# %%
from skimage.io import imread,imsave, imshow
from skimage.color import rgb2gray
import matplotlib.pyplot as plt
import os
from skimage import img_as_ubyte
# Out:
# /home/user/.local/lib/python3.8/site-packages/skimage/io/manage_plugins.py:23: UserWarning: Your installed pillow version is < 7.1.0. Several security issues (CVE-2020-11538, CVE-2020-10379, CVE-2020-10994, CVE-2020-10177) have been fixed in pillow 7.1.0 or higher. We recommend to upgrade this library.
#   from .collection import imread_collection_wrapper

# %%
classe = 'normal' #altere para a classe desejada

path = "/home/user/Documentos/visão_computacional_2022/RIM-ONE_DL_images/partitioned_by_hospital/test_set/"+classe+'/'
names = os.listdir(path)
images = []

for name in names:
    images.append(imread(path+name))

# %%
names
# Out:
# ['r1_Im107.png',
#  'r1_Im041.png',
#  'r1_Im052.png',
#  'r2_Im033.png',
#  'r2_Im023.png',
#  'r1_Im001.png',
#  'r2_Im031.png',
#  'r1_Im012.png',
#  'r1_Im071.png',
#  'r1_Im063.png',
#  'r1_Im019.png',
#  'r1_Im004.png',
#  'r1_Im154.png',
#  'r1_Im156.png',
#  'r2_Im013.png',
#  'r2_Im014.png',
#  'r1_Im057.png',
#  'r1_Im128.png',
#  'r1_Im056.png',
#  'r1_Im020.png',
#  'r1_Im015.png',
#  'r1_Im169.png',
#  'r1_Im125.png',
#  'r1_Im136.png',
#  'r2_Im011.png',
#  'r1_Im162.png',
#  'r1_Im058.png',
#  'r1_Im168.png',
#  'r2_Im026.png',
#  'r2_Im006.png',
#  'r1_Im033.png',
#  'r1_Im026.png',
#  'r2_Im025.png',
#  'r1_Im151.png',
#  'r1_Im150.png',
#  'r1_Im143.png',
#  'r1_Im116.png',
#  'r1_Im133.png',
#  'r1_Im108.png',
#  'r1_Im145.png',
#  'r1_Im031.png',
#  'r2_Im022.png',
#  'r1_Im036.png',
#  'r2_Im032.png',
#  'r1_Im127.png',
#  'r1_Im040.png',
#  'r1_Im080.png',
#  'r2_Im017.png',
#  'r1_Im054.png',
#  'r1_Im146.png',
#  'r1_Im138.png',
#  'r2_Im027.png',
#  'r1_Im131.png',
#  'r1_Im059.png',
#  'r2_Im030.png',
#  'r1_Im055.png',
#  'r2_Im001.png',
#  'r2_Im004.png',
#  'r1_Im163.png',
#  'r1_Im073.png',
#  'r1_Im087.png',
#  'r1_Im028.png',
#  'r2_Im010.png',
#  'r1_Im130.png',
#  'r1_Im152.png',
#  'r1_Im164.png',
#  'r1_Im142.png',
#  'r1_Im025.png',
#  'r1_Im046.png',
#  'r2_Im021.png',
#  'r1_Im008.png',
#  'r1_Im042.png',
#  'r2_Im019.png',
#  'r1_Im153.png',
#  'r1_Im082.png',
#  'r1_Im159.png',
#  'r1_Im161.png',
#  'r1_Im155.png',
#  'r1_Im047.png',
#  'r1_Im022.png',
#  'r1_Im050.png',
#  'r2_Im029.png',
#  'r1_Im014.png',
#  'r1_Im115.png',
#  'r1_Im072.png',
#  'r2_Im028.png',
#  'r1_Im062.png',
#  'r2_Im020.png',
#  'r1_Im006.png',
#  'r1_Im132.png',
#  'r1_Im024.png',
#  'r2_Im016.png',
#  'r2_Im009.png',
#  'r2_Im012.png',
#  'r1_Im129.png',
#  'r1_Im165.png',
#  'r2_Im003.png',
#  'r1_Im032.png',
#  'r1_Im037.png',
#  'r2_Im015.png',
#  'r1_Im166.png',
#  'r1_Im137.png',
#  'r1_Im023.png',
#  'r1_Im119.png',
#  'r1_Im095.png',
#  'r1_Im027.png',
#  'r1_Im011.png',
#  'r1_Im060.png',
#  'r1_Im149.png',
#  'r2_Im018.png',
#  'r2_Im007.png',
#  'r1_Im029.png',
#  'r1_Im003.png',
#  'r1_Im086.png',
#  'r2_Im005.png',
#  'r2_Im002.png',
#  'r1_Im061.png',
#  'r2_Im024.png']

# %%
gray_images = []

for image in images:
    gray_images.append(rgb2gray(image))

# %%
def negativo(imagem, L=256):
  return (L-1)-imagem

# %%
new_gray_images = []

for image in gray_images: #negative
    new_gray_images.append(negativo(image))
path = '/home/user/Documentos/visão_computacional_2022/trabalho_negativo/'+classe+'/'
os.makedirs(path)

for i in range(len(new_gray_images)): #save images
    imsave(path+names[i], new_gray_images[i])
# Out:
# Lossy conversion from float64 to uint8. Range [254.5230431372549, 254.8987894117647]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [254.32072352941177, 254.89647333333335]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [254.27091843137254, 254.8424282352941]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [254.35341411764705, 254.85527921568627]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [254.1391388235294, 254.76461215686274]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [254.3439694117647, 254.82411254901962]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [254.41173176470588, 254.85925333333333]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [254.34704352941176, 254.79941019607844]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [254.4241250980392, 254.89567843137254]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [254.19994784313727, 254.79644]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [254.3275031372549, 254.73247647058824]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [254.32377411764705, 254.96333333333334]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [254.40330235294118, 254.90690745098038]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [254.4898349019608, 254.8639180392157]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [254.28343529411765, 254.71709568627452]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [254.18441921568626, 254.7047874509804]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [254.4444305882353, 254.80115294117647]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [254.66070588235294, 254.96180588235293]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [254.27626352941178, 254.86577647058823]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [254.3157156862745, 254.71965529411764]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [254.38450235294118, 254.92920784313725]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [254.34849843137255, 254.87123960784314]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [254.34764078431374, 254.8293768627451]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [254.54128627450982, 254.92587450980392]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [254.34697607843137, 254.7368243137255]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [254.5340788235294, 254.8916019607843]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [254.40426784313726, 254.84960352941175]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [254.37585137254902, 254.89547098039216]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [254.1503976470588, 254.78382352941176]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [254.27303960784315, 254.72779764705882]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [254.39515960784314, 254.8057843137255]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [254.52360588235294, 254.82760509803921]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [254.16446980392158, 254.74076156862745]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [254.61393764705883, 254.93772235294117]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [254.4951737254902, 254.93667019607844]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [254.40918117647058, 254.93254117647058]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [254.4060631372549, 254.86080274509803]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [254.45086588235293, 254.8552756862745]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [254.