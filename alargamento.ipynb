# %%
from skimage.io import imread,imsave, imshow
from skimage.color import rgb2gray
import matplotlib.pyplot as plt
import os
from skimage import img_as_ubyte
# Out:
# /home/user/.local/lib/python3.8/site-packages/skimage/io/manage_plugins.py:23: UserWarning: Your installed pillow version is < 7.1.0. Several security issues (CVE-2020-11538, CVE-2020-10379, CVE-2020-10994, CVE-2020-10177) have been fixed in pillow 7.1.0 or higher. We recommend to upgrade this library.
#   from .collection import imread_collection_wrapper

# %%
classe = 'normal' #altere para a classe desejada

path = "/home/user/Documentos/visão_computacional_2022/RIM-ONE_DL_images/partitioned_by_hospital/test_set/"+classe+'/'
names = os.listdir(path)

images = []

for name in names:
    images.append(imread(path+name))

# %%
gray_images = []

for image in images:
    gray_images.append(rgb2gray(image))

# %%
def alargamento_contraste(imagem, k, e):
  return (1/(1+(k/imagem)**e))

# %%
param = [(1,2),(1,3), (2,1), (3,1)] # param = (k,e)

for i in param:

    new_gray_images = []

    for image in gray_images: #enhanced contrast
        new_gray_images.append(alargamento_contraste(image, i[0],i[1]))
    path = '/home/user/Documentos/visão_computacional_2022/trabalho_alargamento_contraste/'+classe+str(' ')+str(i[0])+str(',')+str(i[1])+'/'
    os.mkdir(path)
    
    for j in range(len(new_gray_images)): #save images
        imsave(path+names[j], img_as_ubyte(new_gray_images[j]))
# Out:
# <ipython-input-10-0d02a23cdbd9>:13: UserWarning: /home/user/Documentos/visão_computacional_2022/trabalho_alargamento_contraste/normal 1,3/r1_Im128.png is a low contrast image
#   imsave(path+names[j], img_as_ubyte(new_gray_images[j]))
# <ipython-input-10-0d02a23cdbd9>:13: UserWarning: /home/user/Documentos/visão_computacional_2022/trabalho_alargamento_contraste/normal 1,3/r1_Im151.png is a low contrast image
#   imsave(path+names[j], img_as_ubyte(new_gray_images[j]))
# <ipython-input-10-0d02a23cdbd9>:13: UserWarning: /home/user/Documentos/visão_computacional_2022/trabalho_alargamento_contraste/normal 1,3/r1_Im153.png is a low contrast image
#   imsave(path+names[j], img_as_ubyte(new_gray_images[j]))
# <ipython-input-10-0d02a23cdbd9>:13: UserWarning: /home/user/Documentos/visão_computacional_2022/trabalho_alargamento_contraste/normal 1,3/r1_Im159.png is a low contrast image
#   imsave(path+names[j], img_as_ubyte(new_gray_images[j]))
# ...

# %%
imshow(new_gray_images[0], cmap='gray')

# %%
imshow(gray_images[0], cmap='gray')
