# %%
from skimage.io import imread,imsave, imshow
from skimage.color import rgb2gray
import matplotlib.pyplot as plt
import os
from skimage import img_as_ubyte
import numpy as np

# %%
classe = 'normal' #altere para a classe desejada

path = "/home/user/Documentos/visão_computacional_2022/RIM-ONE_DL_images/partitioned_by_hospital/test_set/"+classe+'/'
names = os.listdir(path)
images = []

for name in names:
    images.append(imread(path+name))

# %%
gray_images = []

for image in images:
    gray_images.append(rgb2gray(image))

# %%
def logarit(imagem, c=1):
  return (c * np.log(imagem+1))

# %%
param = [3, 9, 10, 8]

for p in param:
    new_gray_images = []

    for image in gray_images: #negative
        new_gray_images.append(logarit(image, p))
    path = '/home/user/Documentos/visão_computacional_2022/trabalho_logaritmico/'+classe+str(' c=')+str(p)+'/'
    os.makedirs(path)

    for i in range(len(new_gray_images)): #save images
        imsave(path+names[i], new_gray_images[i])
# Out:
# Lossy conversion from float64 to uint8. Range [0.2892303282577573, 1.1699513913826352]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.29553333586973873, 1.5550890851409687]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.4389735144067498, 1.6427711470614232]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.4054822523214314, 1.4961119460853243]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.6341548914146048, 1.863118136031083]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.4860694198433344, 1.5132705808471703]. Convert image to uint8 prior to saving to suppress this warning.
# ...
